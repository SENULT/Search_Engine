# %% [markdown]
# # Text Processing for Vietnamese Football News
#
# Notebook này xử lý dữ liệu bóng đá từ MongoDB, bao gồm:
# - Kết nối MongoDB
# - Làm sạch và chuẩn hóa văn bản tiếng Việt
# - Tách từ và loại bỏ stopwords
# - Trích xuất entities (đội bóng, cầu thủ, giải đấu)
# - Phân tích tần suất từ và n-grams

# %% [markdown]
# ## 1. Import Libraries

# %%
import os
import json
import re
from pymongo import MongoClient
import pandas as pd
from datetime import datetime
import certifi
from collections import Counter
from tqdm import tqdm
from itertools import islice
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
# Text processing libraries - PyVi
try:
    from pyvi import ViTokenizer, ViPosTagger
    PYVI_AVAILABLE = True
    print("✓ PyVi đã được cài đặt")
except ImportError:
    print("✗ PyVi chưa cài đặt. Cài đặt bằng: pip install pyvi")
    PYVI_AVAILABLE = False
# Out:
# ✓ PyVi đã được cài đặt

# %%
# Text processing libraries - spaCy
try:
    import spacy
    nlp = spacy.load("vi_core_news_sm")
    SPACY_AVAILABLE = True
    print("✓ spaCy Vietnamese model đã được cài đặt")
except:
    print("✗ spaCy Vietnamese model chưa có. Cài đặt bằng: python -m spacy download vi_core_news_sm")
    SPACY_AVAILABLE = False
# Out:
# ✗ spaCy Vietnamese model chưa có. Cài đặt bằng: python -m spacy download vi_core_news_sm

# %% [markdown]
# ## 2. MongoDB Configuration

# %%
# MongoDB connection
MONGO_URI = "mongodb+srv://group2user1:eRqZZqR3VQA4NPLd@cluster0.orljj0v.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
DB_NAME = "vnexpress_db"
COLLECTION_NAME = "vnexpress_bongda"

print(f"Database: {DB_NAME}")
print(f"Collection: {COLLECTION_NAME}")
# Out:
# Database: vnexpress_db
# Collection: vnexpress_bongda

# %% [markdown]
# ## 3. Vietnamese Text Processor Class

# %%
class VietnameseTextProcessor:
    def __init__(self):
        # Vietnamese stopwords
        self.stop_words = set([
            'và', 'của', 'trong', 'với', 'là', 'có', 'được', 'cho', 'từ', 'một', 'các',
            'để', 'không', 'sẽ', 'đã', 'về', 'hay', 'theo', 'như', 'cũng', 'này', 'đó',
            'khi', 'những', 'tại', 'sau', 'bị', 'giữa', 'trên', 'dưới', 'ngoài',
            'thì', 'nhưng', 'mà', 'hoặc', 'nếu', 'vì', 'do', 'nên', 'rồi', 'còn', 'đều',
            'chỉ', 'việc', 'người', 'lại', 'đây', 'đấy', 'ở', 'ra', 'vào', 'lên', 'xuống'
        ])
        
        # Football-specific entities
        self.football_teams = [
            'hà nội fc', 'hoàng anh gia lai', 'sài gòn fc', 'than quảng ninh', 'viettel fc',
            'becamex bình dương', 'slna', 'đà nẵng', 'nam định', 'hải phòng fc', 'hcm city',
            'song lam nghệ an', 'quảng nam', 'khánh hòa', 'đội tuyển việt nam', 'tuyển việt nam'
        ]
        
        self.player_patterns = [
            r'cầu thủ\s+([A-Za-zÀ-ỹ\s]{3,30})',
            r'tiền đạo\s+([A-Za-zÀ-ỹ\s]{3,30})',
            r'thủ môn\s+([A-Za-zÀ-ỹ\s]{3,30})',
            r'hậu vệ\s+([A-Za-zÀ-ỹ\s]{3,30})',
            r'tiền vệ\s+([A-Za-zÀ-ỹ\s]{3,30})',
            r'HLV\s+([A-Za-zÀ-ỹ\s]{3,30})',
            r'huấn luyện viên\s+([A-Za-zÀ-ỹ\s]{3,30})'
        ]
        
        self.competitions = [
            'v-league', 'v.league', 'v league', 'cup quốc gia', 'aff cup', 'sea games',
            'world cup', 'asian cup', 'champions league', 'afc cup', 'u23', 'u22', 'u19'
        ]
    
    def clean_text(self, text):
        """Làm sạch và chuẩn hóa text tiếng Việt"""
        if not text:
            return ""
        
        text = re.sub(r'\s+', ' ', text)
        text = re.sub(r'[^\w\sàáảãạăắằẳẵặâấầẩẫậèéẻẽẹêếềểễệìíỉĩịòóỏõọôốồổỗộơớờởỡợùúủũụưứừửữựỳýỷỹỵđĐ]', ' ', text)
        text = text.lower()
        text = re.sub(r'\s+', ' ', text).strip()
        return text
    
    def tokenize_vietnamese(self, text):
        """Tách từ tiếng Việt"""
        if PYVI_AVAILABLE:
            try:
                return ViTokenizer.tokenize(text).split()
            except:
                pass
        return text.split()
    
    def remove_stopwords(self, tokens):
        return [token for token in tokens if token not in self.stop_words and len(token) > 1]
    
    def extract_entities(self, text):
        entities = {'teams': [], 'players': [], 'competitions': []}
        text_lower = text.lower()
        
        for team in self.football_teams:
            if team in text_lower:
                entities['teams'].append(team)
        
        for pattern in self.player_patterns:
            matches = re.finditer(pattern, text, re.IGNORECASE)
            for match in matches:
                player_name = match.group(1).strip()
                if len(player_name) > 3:
                    entities['players'].append(player_name)
        
        for comp in self.competitions:
            if comp in text_lower:
                entities['competitions'].append(comp)
        
        return entities
    
    def process_document(self, doc):
        title = doc.get('title', '')
        content = doc.get('content', '')
        full_text = f"{title} {content}"
        
        cleaned_text = self.clean_text(full_text)
        tokens = self.tokenize_vietnamese(cleaned_text)
        filtered_tokens = self.remove_stopwords(tokens)
        entities = self.extract_entities(full_text)
        
        return {
            'doc_id': str(doc.get('_id', '')),
            'title': title,
            'url': doc.get('url', ''),
            'date': doc.get('date', ''),
            'author': doc.get('author', ''),
            'original_length': len(full_text),
            'cleaned_text': cleaned_text,
            'tokens': tokens,
            'filtered_tokens': filtered_tokens,
            'token_count': len(tokens),
            'filtered_count': len(filtered_tokens),
            'entities': entities,
            'entity_count': sum(len(entities[key]) for key in entities)
        }

print("✓ VietnameseTextProcessor class đã được định nghĩa")
# Out:
# ✓ VietnameseTextProcessor class đã được định nghĩa

# %% [markdown]
# ## 4. Database Functions

# %%
def connect_to_database():
    """Kết nối tới MongoDB"""
    try:
        client = MongoClient(MONGO_URI, tls=True, tlsCAFile=certifi.where())
        db = client[DB_NAME]
        collection = db[COLLECTION_NAME]
        doc_count = collection.count_documents({})
        print(f"✓ Kết nối database thành công!")
        print(f"  Tổng số documents: {doc_count}")
        return client, db, collection
    except Exception as e:
        print(f"✗ Lỗi kết nối database: {e}")
        return None, None, None

print("✓ Database functions đã được định nghĩa")
# Out:
# ✓ Database functions đã được định nghĩa

# %% [markdown]
# ## 5. Document Processing Functions

# %%
def process_all_documents(collection, limit=None):
    """Xử lý tất cả documents từ collection"""
    processor = VietnameseTextProcessor()
    if limit:
        documents = collection.find().limit(limit)
        total_docs = limit
    else:
        documents = collection.find()
        total_docs = collection.count_documents({})
    
    print(f"Bắt đầu xử lý {total_docs} documents...")
    processed_results, error_count = [], 0
    
    for doc in tqdm(documents, desc="Processing documents", total=total_docs):
        try:
            result = processor.process_document(doc)
            processed_results.append(result)
        except Exception as e:
            error_count += 1
            print(f"Lỗi xử lý document {doc.get('_id', 'unknown')}: {e}")
    
    print(f"✓ Hoàn thành! Xử lý thành công: {len(processed_results)}, Lỗi: {error_count}")
    return processed_results

print("✓ process_all_documents function đã được định nghĩa")
# Out:
# ✓ process_all_documents function đã được định nghĩa

# %% [markdown]
# ## 6. Analysis Functions

# %%
def analyze_results(results):
    """Phân tích kết quả xử lý"""
    print("\nPHÂN TÍCH KẾT QUẢ:")
    print(f"Tổng số documents đã xử lý: {len(results)}")
    
    token_counts = [r['token_count'] for r in results]
    filtered_counts = [r['filtered_count'] for r in results]
    entity_counts = [r['entity_count'] for r in results]
    
    print(f"\nThống kê Tokens:")
    print(f"  - Trung bình tokens/document: {sum(token_counts)/len(token_counts):.1f}")
    print(f"  - Trung bình filtered tokens/document: {sum(filtered_counts)/len(filtered_counts):.1f}")
    print(f"  - Trung bình entities/document: {sum(entity_counts)/len(entity_counts):.1f}")
    
    all_teams, all_players, all_competitions = [], [], []
    for r in results:
        all_teams.extend(r['entities']['teams'])
        all_players.extend(r['entities']['players'])
        all_competitions.extend(r['entities']['competitions'])
    
    print(f"\nTop 10 Đội bóng được nhắc đến nhiều nhất:")
    for team, count in Counter(all_teams).most_common(10):
        print(f"  - {team}: {count} lần")
    
    print(f"\nTop 10 Cầu thủ được nhắc đến nhiều nhất:")
    for player, count in Counter(all_players).most_common(10):
        print(f"  - {player}: {count} lần")
    
    print(f"\nTop 10 Giải đấu được nhắc đến nhiều nhất:")
    for comp, count in Counter(all_competitions).most_common(10):
        print(f"  - {comp}: {count} lần")

print("✓ analyze_results function đã được định nghĩa")
# Out:
# ✓ analyze_results function đã được định nghĩa

# %%
def save_results(results, filename="processed_data.json"):
    """Lưu kết quả ra file JSON"""
    # Tạo folder outputs nếu chưa có
    output_dir = os.path.join("d:\\data\\Search_Engine", "outputs")
    os.makedirs(output_dir, exist_ok=True)
    
    filepath = os.path.join(output_dir, filename)
    with open(filepath, 'w', encoding='utf-8') as f:
        json.dump(results, f, ensure_ascii=False, indent=2, default=str)
    print(f"✓ Đã lưu kết quả vào {filepath}")

print("✓ save_results function đã được định nghĩa")
# Out:
# ✓ save_results function đã được định nghĩa

# %% [markdown]
# ## 7. Word Frequency Analysis

# %%
def analyze_multiple_documents(collection, processor, n=50, top_n=50, filename=None):
    """Lấy ngẫu nhiên n documents, gộp tokens và tính tần suất chung"""
    docs = collection.aggregate([{"$sample": {"size": n}}])
    all_tokens = []
    
    for idx, doc in enumerate(docs, 1):
        result = processor.process_document(doc)
        tokens = result["filtered_tokens"]
        all_tokens.extend(tokens)   # gộp tất cả tokens lại
    
    # Tính tần suất từ toàn bộ tokens
    counter = Counter(all_tokens)
    total = sum(counter.values())
    
    data = []
    for i, (word, freq) in enumerate(counter.most_common(top_n), 1):
        Pr = freq / total * 100
        data.append({
            "Word": word,
            "Freq": freq,
            "r": i,
            "Pr(%)": round(Pr, 2),
            "r*Pr": round(i * Pr / 100, 3)
        })
    
    df = pd.DataFrame(data)
    print(df.to_string(index=False))
    
    # Tạo folder outputs nếu chưa có
    output_dir = os.path.join("d:\\data\\Search_Engine", "outputs")
    os.makedirs(output_dir, exist_ok=True)
    
    # Xuất file CSV
    if not filename:
        filename = f"wordfreq_{n}docs_total_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
    
    filepath = os.path.join(output_dir, filename)
    df.to_csv(filepath, index=False, encoding="utf-8-sig")
    print(f"\n✓ Đã lưu kết quả {n} documents (gộp) vào: {filepath}")
    
    return df

print("✓ analyze_multiple_documents function đã được định nghĩa")
# Out:
# ✓ analyze_multiple_documents function đã được định nghĩa

# %% [markdown]
# ## 8. N-grams Analysis
#
# ### Hàm phân tích N-grams

# %%
def generate_ngrams(tokens, n):
    """Sinh n-grams từ list tokens"""
    return [' '.join(tokens[i:i+n]) for i in range(len(tokens)-n+1)]

print("✓ generate_ngrams function đã được định nghĩa")
# Out:
# ✓ generate_ngrams function đã được định nghĩa

# %%
def analyze_ngrams_combined(collection, processor, n_docs=1800, max_n=5, top_k=50, filename=None):
    """
    Phân tích n-grams (1 -> max_n), lưu tất cả vào 1 file CSV duy nhất
    """
    docs = collection.aggregate([{"$sample": {"size": n_docs}}])

    all_tokens_list = []
    for doc in docs:
        result = processor.process_document(doc)
        all_tokens_list.append(result["filtered_tokens"])

    all_data = []

    for n in range(1, max_n+1):
        ngrams_all = []
        for tokens in all_tokens_list:
            ngrams_all.extend(generate_ngrams(tokens, n))
        
        counter = Counter(ngrams_all)
        for phrase, freq in counter.most_common(top_k):
            all_data.append({
                "n": n,
                "Frequency": freq,
                "Phrase": phrase
            })
    
    df = pd.DataFrame(all_data)

    # Tạo folder outputs nếu chưa có
    output_dir = os.path.join("d:\\data\\Search_Engine", "outputs")
    os.makedirs(output_dir, exist_ok=True)
    
    if not filename:
        filename = f"ngrams_combined_{n_docs}docs_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
    
    filepath = os.path.join(output_dir, filename)
    df.to_csv(filepath, index=False, encoding="utf-8-sig")
    print(f"✓ Đã lưu kết quả n-grams (1-{max_n}) vào: {filepath}")
    
    return df

print("✓ analyze_ngrams_combined function đã được định nghĩa")
# Out:
# ✓ analyze_ngrams_combined function đã được định nghĩa

# %%
def analyze_single_ngram(collection, processor, n=1, n_docs=1800, top_k=100, filename=None):
    """
    Phân tích một loại n-gram cụ thể (1-gram, 2-gram, etc.)
    """
    docs = collection.aggregate([{"$sample": {"size": n_docs}}])

    all_tokens_list = []
    print(f"\nĐang xử lý {n_docs} documents cho {n}-gram...")
    for doc in tqdm(docs, desc=f"Processing {n}-gram", total=n_docs):
        result = processor.process_document(doc)
        all_tokens_list.append(result["filtered_tokens"])

    # Sinh n-grams
    ngrams_all = []
    for tokens in all_tokens_list:
        ngrams_all.extend(generate_ngrams(tokens, n))
    
    # Đếm tần suất
    counter = Counter(ngrams_all)
    total = sum(counter.values())
    
    data = []
    for i, (phrase, freq) in enumerate(counter.most_common(top_k), 1):
        Pr = freq / total * 100
        data.append({
            "Rank": i,
            "Phrase": phrase,
            "Frequency": freq,
            "Pr(%)": round(Pr, 2)
        })
    
    df = pd.DataFrame(data)
    print(f"\n{'='*80}")
    print(f"TOP {top_k} {n}-GRAM")
    print(f"{'='*80}")
    print(df.to_string(index=False))
    
    # Tạo folder outputs nếu chưa có
    output_dir = os.path.join("d:\\data\\Search_Engine", "outputs")
    os.makedirs(output_dir, exist_ok=True)
    
    # Lưu file
    if not filename:
        ngram_names = {1: "unigram", 2: "bigram", 3: "trigram", 4: "fourgram", 5: "fivegram"}
        name = ngram_names.get(n, f"{n}gram")
        filename = f"{name}_{n_docs}docs_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
    
    filepath = os.path.join(output_dir, filename)
    df.to_csv(filepath, index=False, encoding="utf-8-sig")
    print(f"\n✓ Đã lưu kết quả {n}-gram vào: {filepath}")
    
    return df

print("✓ analyze_single_ngram function đã được định nghĩa")
# Out:
# ✓ analyze_single_ngram function đã được định nghĩa

# %% [markdown]
# ---
#
# ## 8.1. Phân Tích Từng Loại N-gram
#
# ### Chạy các cell bên dưới để phân tích từng loại n-gram riêng biệt

# %% [markdown]
# ### Bước 1: Kết nối Database và khởi tạo Processor
#
# Nếu chưa kết nối, chạy cell này:

# %%
# Kết nối database và khởi tạo processor (nếu chưa làm)
try:
    # Kiểm tra xem đã kết nối chưa
    collection.count_documents({})
    print("✓ Đã có kết nối database")
except:
    print("Đang kết nối database...")
    client, db, collection = connect_to_database()
    
try:
    # Kiểm tra processor
    processor
    print("✓ Đã có processor")
except:
    print("Đang khởi tạo processor...")
    processor = VietnameseTextProcessor()
    print("✓ Processor đã sẵn sàng")
# Out:
# ✓ Đã có kết nối database
# ✓ Đã có processor

# %% [markdown]
# ### Bước 2: Phân tích 1-gram (Unigram)
#
# Phân tích các từ đơn xuất hiện nhiều nhất:

# %%
# Phân tích 1-gram (Unigram)
df_unigram = analyze_single_ngram(collection, processor, n=1, n_docs=1830, top_k=100)
# Out:
# Đang xử lý 1830 documents cho 1-gram...
# Processing 1-gram:   0%|          | 0/1830 [00:00<?, ?it/s]
# ================================================================================
# TOP 100 1-GRAM
# ================================================================================
# Empty DataFrame
# Columns: []
# Index: []
#
# ✓ Đã lưu kết quả 1-gram vào: d:\data\Search_Engine\outputs\unigram_1830docs_20251010_165755.csv

# %% [markdown]
# ### Bước 3: Phân tích 2-gram (Bigram)
#
# Phân tích các cặp từ liên tiếp xuất hiện nhiều nhất:

# %%
# Phân tích 2-gram (Bigram)
df_bigram = analyze_single_ngram(collection, processor, n=2, n_docs=1830, top_k=100)
# Out:
# Đang xử lý 1830 documents cho 2-gram...
# Processing 2-gram:   0%|          | 0/1830 [00:00<?, ?it/s]
# ================================================================================
# TOP 100 2-GRAM
# ================================================================================
# Empty DataFrame
# Columns: []
# Index: []
#
# ✓ Đã lưu kết quả 2-gram vào: d:\data\Search_Engine\outputs\bigram_1830docs_20251010_165755.csv

# %% [markdown]
# ### Bước 4: Phân tích 3-gram (Trigram)
#
# Phân tích các cụm 3 từ liên tiếp xuất hiện nhiều nhất:

# %%
# Phân tích 3-gram (Trigram)
df_trigram = analyze_single_ngram(collection, processor, n=3, n_docs=1830, top_k=100)
# Out:
# Đang xử lý 1830 documents cho 3-gram...
# Processing 3-gram:   0%|          | 0/1830 [00:00<?, ?it/s]
# ================================================================================
# TOP 100 3-GRAM
# ================================================================================
# Empty DataFrame
# Columns: []
# Index: []
#
# ✓ Đã lưu kết quả 3-gram vào: d:\data\Search_Engine\outputs\trigram_1830docs_20251010_165756.csv

# %% [markdown]
# ### Bước 5: Phân tích 4-gram (Four-gram)
#
# Phân tích các cụm 4 từ liên tiếp xuất hiện nhiều nhất:

# %%
# Phân tích 4-gram (Four-gram)
df_fourgram = analyze_single_ngram(collection, processor, n=4, n_docs=1830, top_k=100)
# Out:
# Đang xử lý 1830 documents cho 4-gram...
# Processing 4-gram:   0%|          | 0/1830 [00:00<?, ?it/s]
# ================================================================================
# TOP 100 4-GRAM
# ================================================================================
# Empty DataFrame
# Columns: []
# Index: []
#
# ✓ Đã lưu kết quả 4-gram vào: d:\data\Search_Engine\outputs\fourgram_1830docs_20251010_165756.csv

# %% [markdown]
# ### Bước 6: Phân tích 5-gram (Five-gram)
#
# Phân tích các cụm 5 từ liên tiếp xuất hiện nhiều nhất:

# %%
# Phân tích 5-gram (Five-gram)
df_fivegram = analyze_single_ngram(collection, processor, n=5, n_docs=1830, top_k=100)
# Out:
# Đang xử lý 1830 documents cho 5-gram...
# Processing 5-gram:   0%|          | 0/1830 [00:00<?, ?it/s]
# ================================================================================
# TOP 100 5-GRAM
# ================================================================================
# Empty DataFrame
# Columns: []
# Index: []
#
# ✓ Đã lưu kết quả 5-gram vào: d:\data\Search_Engine\outputs\fivegram_1830docs_20251010_165756.csv

# %% [markdown]
# ### Bước 7: Tổng hợp tất cả N-grams (Optional)
#
# Nếu muốn lưu tất cả n-grams vào 1 file duy nhất:

# %%
# Phân tích và lưu tất cả n-grams vào 1 file
df_all_ngrams = analyze_ngrams_combined(collection, processor, n_docs=1830, max_n=5, top_k=100)
# Out:
# ✓ Đã lưu kết quả n-grams (1-5) vào: d:\data\Search_Engine\outputs\ngrams_combined_1830docs_20251010_165756.csv

# %% [markdown]
# ## 9. Main Execution
#
# ### Chạy cell bên dưới để thực hiện toàn bộ quy trình xử lý

# %%
def main():
    print("BẮT ĐẦU XỬ LÝ TEXT TỪ MONGODB")
    print("=" * 50)
    
    client, db, collection = connect_to_database()
    if collection is None:
        print("Không thể kết nối database!")
        return
    
    # Xử lý một số documents mẫu
    results = process_all_documents(collection, limit=5)  
    if results:
        analyze_results(results)
        save_results(results, f"processed_vnexpress_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json")
    
    # Phân tích từ vựng
    processor = VietnameseTextProcessor()
    analyze_multiple_documents(collection, processor, n=50, top_n=50)
    
    # Phân tích n-grams
    analyze_and_save_ngrams(collection, processor, n_docs=1830, max_n=5, top_k=100)

    client.close()
    print("\n✓ Đã đóng kết nối database")
    print("✓ HOÀN THÀNH!")

print("✓ main function đã được định nghĩa")
# Out:
# ✓ main function đã được định nghĩa

# %% [markdown]
# ### Chạy toàn bộ quy trình
#
# Chạy cell bên dưới để thực thi:

# %%
def main():
    print("BẮT ĐẦU XỬ LÝ TEXT TỪ MONGODB")
    print("=" * 50)
    
    # Tạo folder outputs
    output_dir = os.path.join("d:\\data\\Search_Engine", "outputs")
    os.makedirs(output_dir, exist_ok=True)
    print(f"✓ Folder outputs: {output_dir}\n")
    
    client, db, collection = connect_to_database()
    if collection is None:
        print("Không thể kết nối database!")
        return
    
    # Xử lý một số documents mẫu
    results = process_all_documents(collection, limit=5)  
    if results:
        analyze_results(results)
        save_results(results, f"processed_vnexpress_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json")
    
    # Phân tích từ vựng
    processor = VietnameseTextProcessor()
    analyze_multiple_documents(collection, processor, n=50, top_n=50)
    
    # Phân tích từng loại n-gram riêng biệt
    print("\n" + "="*80)
    print("BẮT ĐẦU PHÂN TÍCH N-GRAMS")
    print("="*80)
    
    for n in range(1, 6):
        analyze_single_ngram(collection, processor, n=n, n_docs=1830, top_k=100)
        print("\n")

    client.close()
    print("\n✓ Đã đóng kết nối database")
    print("✓ HOÀN THÀNH!")
    print(f"\n📁 Tất cả kết quả đã được lưu vào folder: {output_dir}")

print("✓ main function đã được định nghĩa")

# Chạy toàn bộ quy trình xử lý
if __name__ == "__main__":
    main()
# Out:
# ✓ main function đã được định nghĩa
# BẮT ĐẦU XỬ LÝ TEXT TỪ MONGODB
# ==================================================
# ✓ Folder outputs: d:\data\Search_Engine\outputs
#
# ✓ Kết nối database thành công!
#   Tổng số documents: 1838
# Bắt đầu xử lý 5 documents...
# Processing documents: 100%|██████████| 5/5 [00:00<00:00, 14.20it/s]
# ✓ Hoàn thành! Xử lý thành công: 5, Lỗi: 0
#
# PHÂN TÍCH KẾT QUẢ:
# Tổng số documents đã xử lý: 5
#
# Thống kê Tokens:
#   - Trung bình tokens/document: 727.4
#   - Trung bình filtered tokens/document: 541.4
#   - Trung bình entities/document: 19.2
#
# Top 10 Đội bóng được nhắc đến nhiều nhất:
#   - nam định: 2 lần
#   - tuyển việt nam: 2 lần
#   - hà nội fc: 1 lần
#   - đà nẵng: 1 lần
#   - đội tuyển việt nam: 1 lần
#
# Top 10 Cầu thủ được nhắc đến nhiều nhất:
#   - Kim Sang: 3 lần
#   - Park Hang: 2 lần
#   - trẻ cần được thi đấu thường xu: 1 lần
#   - nhập tịch vì sử dụng giấy tờ g: 1 lần
#   - vào sân: 1 lần
#   - bị phạt: 1 lần
#   - của Quy định này có đoạn: 1 lần
#   - phải được đăng ký đúng quy địn: 1 lần
#   - được coi là đủ tư cách thi đấu: 1 lần
#   - hợp lệ: 1 lần
#
# Top 10 Giải đấu được nhắc đến nhiều nhất:
#   - u23: 4 lần
#   - world cup: 3 lần
#   - asian cup: 3 lần
#   - v-league: 2 lần
#   - champions league: 1 lần
#   - aff cup: 1 lần
# ✓ Đã lưu kết quả vào d:\data\Search_Engine\outputs\processed_vnexpress_20251010_165758.json
#     Word  Freq  r  Pr(%)  r*Pr
#      đội   231  1   1.13 0.011
#     trận   224  2   1.10 0.022
#      nam   203  3   0.99 0.030
#   league   197  4   0.97 0.039
#      hlv   195  5   0.96 0.048
#     bóng   180  6   0.88 0.053
#      hai   180  7   0.88 0.062
#  cầu_thủ   165  8   0.81 0.065
#     việt   151  9   0.74 0.067
#      năm   149 10   0.73 0.073
#      đến   137 11   0.67 0.074
#      bàn   129 12   0.63 0.076
#      sân   124 13   0.61 0.079
#     vòng   122 14   0.60 0.084
#    trước   121 15   0.59 0.089
#       họ   109 16   0.53 0.085
#     định   106 17   0.52 0.088
#    nhiều   105 18   0.51 0.093
#      mùa   102 19   0.50 0.095
#    thắng   100 20   0.49 0.098
#      clb   100 21   0.49 0.103
#     phải    99 22   0.49 0.107
#  thi_đấu    99 23   0.49 0.112
#     nhất    98 24   0.48 0.115
#     giải    96 25   0.47 0.118
#     phút    94 26   0.46 0.120
#      văn    88 27   0.43 0.116
#       ba    88 28   0.43 0.121
#   nguyễn    86 29   0.42 0.122
#      ông    84 30   0.41 0.124
#      anh    84 31   0.41 0.128
#       đá    84 32   0.41 0.132
#     chưa    82 33   0.40 0.133
#     hagl    81 34   0.40 0.135
#     chơi    76 35   0.37 0.130
#     điểm    74 36   0.36 0.131
# việt_nam    74 37   0.36 0.134
#      hải    74 38   0.36 0.138
#     bình    71 39   0.35 0.136
#  bóng_đá    70 40   0.34 0.137
#      hơn    70 41   0.34 0.141
#      đức    69 42   0.34 0.142
#     thua    69 43   0.34 0.145
#   hà_nội    69 44   0.34 0.149
#      thứ    67 45   0.33 0.148
#     đang    66 46   0.32 0.149
#      nhà    66 47   0.32 0.152
#       sự    66 48   0.32 0.155
#    quang    62 49   0.30 0.149
#      lan    59 50   0.29 0.145
#
# ✓ Đã lưu kết quả 50 documents (gộp) vào: d:\data\Search_Engine\outputs\wordfreq_50docs_total_20251010_165800.csv
#
# ================================================================================
# BẮT ĐẦU PHÂN TÍCH N-GRAMS
# ================================================================================
#
# Đang xử lý 1830 documents cho 1-gram...
# Processing 1-gram: 100%|██████████| 1830/1830 [00:38<00:00, 47.93it/s]
# ================================================================================
# TOP 100 1-GRAM
# ================================================================================
#  Rank    Phrase  Frequency  Pr(%)
#     1       nam       8285   1.11
#     2       đội       7738   1.04
#     3      trận       7568   1.02
#     4       hai       6774   0.91
#     5      việt       6748   0.91
#     6   cầu_thủ       6665   0.89
#     7      bóng       5693   0.76
#     8       hlv       5603   0.75
#     9       năm       5196   0.70
#    10    league       5183   0.70
#    11     trước       4806   0.64
#    12       sân       4726   0.63
#    13       đến       4519   0.61
#    14      phải       4324   0.58
#    15       văn       3946   0.53
#    16    nguyễn       3908   0.52
#    17       bàn       3900   0.52
#    18     thắng       3863   0.52
#    19     nhiều       3826   0.51
#    20      phút       3668   0.49
#    21       anh       3643   0.49
#    22      nhất       3543   0.48
#    23      vòng       3482   0.47
#    24       ông       3389   0.45
#    25  việt_nam       3356   0.45
#    26      giải       3261   0.44
#    27        họ       3167   0.42
#    28    hà_nội       3125   0.42
#    29        ba       2987   0.40
#    30   bóng_đá       2975   0.40
#    31       hơn       2974   0.40
#    32       cup       2970   0.40
#    33      điểm       2915   0.39
#    34       thứ       2899   0.39
#    35   thi_đấu       2851   0.38
#    36      ngày       2737   0.37
#    37       mùa       2619   0.35
#    38      định       2617   0.35
#    39      chơi       2615   0.35
#    40       hải       2598   0.35
#    41      thua       2474   0.33
#    42       clb       2466   0.33
#    43       đức       2456   0.33
#    44       tôi       2420   0.32
#    45        đá       2406   0.32
#    46      bình       2382   0.32
#    47 đội_tuyển       2349   0.32
#    48       lần       2296   0.31
#    49       ảnh       2255   0.30
#    50   vô_địch       2241   0.30
#    51       nhà       2231   0.30
#    52      cùng       2175   0.29
#    53      thái       2158   0.29
#    54      hagl       2148   0.29
#    55       vẫn       2030   0.27
#    56  trận_đấu       2015   0.27
#    57      đang       2009   0.27
#    58  tiền_đạo       2004   0.27
#    59       lan       1946   0.26
#    60        sự       1895   0.25
#    61      2024       1886   0.25
#    62      công       1809   0.24
#    63       tốt       1808   0.24
#    64       mới       1762   0.24
#    65      bảng       1745   0.23
#    66       qua       1743   0.23
#    67       cao       1742   0.23
#    68      sang       1679   0.23
#    69    có_thể       1657   0.22
#    70       làm       1614   0.22
#    71    cơ_hội       1604   0.22
#    72   thủ_môn       1569   0.21
#    73        fc       1563   0.21
#    74        đi       1560   0.21
#    75       đầu       1555   0.21
#    76      chưa       1539   0.21
#    77      giúp       1536   0.21
#    78      mạnh       1535   0.21
#    79      tiến       1495   0.20
#    80     hoàng       1492   0.20
#    81     thanh       1489   0.20
#    82      hạng       1485   0.20
#    83      hàng       1481   0.20
#    84       nói       1480   0.20
#    85 trọng_tài       1446   0.19
#    86      cuối       1413   0.19
#    87      lượt       1412   0.19
#    88     tháng       1411   0.19
#    89        10       1407   0.19
#    90       rất       1406   0.19
#    91        12       1401   0.19
#    92      từng       1390   0.19
#    93       gặp       1376   0.18
#    94     quang       1355   0.18
#    95        tp       1347   0.18
#    96       hcm       1339   0.18
#    97     khiến       1320   0.18
#    98 tuy_nhiên       1317   0.18
#    99       hòa       1308   0.18
#   100       kim       1295   0.17
#
# ✓ Đã lưu kết quả 1-gram vào: d:\data\Search_Engine\outputs\unigram_1830docs_20251010_165839.csv
#
#
#
# Đang xử lý 1830 documents cho 2-gram...
# Processing 2-gram: 100%|██████████| 1830/1830 [00:36<00:00, 50.33it/s]
# ================================================================================
# TOP 100 2-GRAM
# ================================================================================
#  Rank           Phrase  Frequency  Pr(%)
#     1         việt nam       5346   0.72
#     2         đội bóng       2046   0.28
#     3         thái lan       1870   0.25
#     4         nam định       1776   0.24
#     5           tp hcm       1337   0.18
#     6        hải phòng       1080   0.15
#     7       bình dương       1053   0.14
#     8        hà_nội fc       1009   0.14
#     9          chủ nhà        982   0.13
#    10        bàn thắng        932   0.13
#    11          hlv kim        871   0.12
#    12        asean cup        816   0.11
#    13        bình định        767   0.10
#    14         mùa giải        761   0.10
#    15          thứ hai        749   0.10
#    16       hiếu lương        721   0.10
#    17        quang hải        678   0.09
#    18     bóng_đá việt        668   0.09
#    19          aff cup        667   0.09
#    20         vòng cấm        665   0.09
#    21          hai đội        648   0.09
#    22         hiệp hai        646   0.09
#    23         sang sik        620   0.08
#    24        đội khách        619   0.08
#    25         kim sang        618   0.08
#    26         hlv park        612   0.08
#    27        tiến linh        596   0.08
#    28        asian cup        594   0.08
#    29         cup 2024        586   0.08
#    30         đông nam        580   0.08
#    31         hai trận        579   0.08
#    32         sinh năm        576   0.08
#    33       nguyễn văn        559   0.08
#    34         mở tỷ_số        555   0.07
#    35         thể công        539   0.07
#    36       ngoại binh        523   0.07
#    37         nhật bản        518   0.07
#    38         đức đồng        517   0.07
#    39      league 2023        510   0.07
#    40        thanh hoá        509   0.07
#    41       trận thắng        509   0.07
#    42           thứ ba        506   0.07
#    43         lối chơi        500   0.07
#    44         văn toàn        499   0.07
#    45      công phượng        485   0.07
#    46        vòng bảng        485   0.07
#    47        hạng nhất        473   0.06
#    48         thầy trò        463   0.06
#    49         hàng thủ        461   0.06
#    50        2024 2025        449   0.06
#    51         gần nhất        434   0.06
#    52         hàn quốc        432   0.06
#    53         trụ hạng        425   0.06
#    54         đứng thứ        424   0.06
#    55         hàng đẫy        408   0.05
#    56         đến phút        400   0.05
#    57        văn quyết        399   0.05
#    58     cầu_thủ việt        397   0.05
#    59 bóng_đá việt_nam        397   0.05
#    60     cup quốc_gia        388   0.05
#    61        hoàng đức        385   0.05
#    62          văn lâm        372   0.05
#    63         vượt qua        371   0.05
#    64     chức vô_địch        371   0.05
#    65   vô_địch league        364   0.05
#    66        trận thua        363   0.05
#    67        tiến dũng        363   0.05
#    68          ảnh đức        362   0.05
#    69        sea games        358   0.05
#    70        park hang        357   0.05
#    71   công_an hà_nội        356   0.05
#    72         hang seo        356   0.05
#    73          hai bàn        355   0.05
#    74         tốt nhất        354   0.05
#    75         duy mạnh        352   0.05
#    76          ảnh lâm        350   0.05
#    77         sân hàng        349   0.05
#    78     nhà cầm_quân        347   0.05
#    79        nhiều hơn        342   0.05
#    80  nguyễn xuân_son        341   0.05
#    81         bên cạnh        341   0.05
#    82       sài_gòn fc        338   0.05
#    83      cầu_thủ trẻ        327   0.04
#    84          lượt đi        326   0.04
#    85         đưa bóng        324   0.04
#    86          phút bù        322   0.04
#    87        ninh bình        314   0.04
#    88        2023 2024        312   0.04
#    89        giải hạng        311   0.04
#    90      league 2024        308   0.04
#    91         tuấn hải        306   0.04
#    92          ba trận        305   0.04
#    93          năm nay        301   0.04
#    94        văn thanh        292   0.04
#    95          đội chủ        290   0.04
#    96         covid 19        289   0.04
#    97          ba điểm        289   0.04
#    98         bàn thua        286   0.04
#    99   ban huấn_luyện        285   0.04
#   100           clb tp        283   0.04
#
# ✓ Đã lưu kết quả 2-gram vào: d:\data\Search_Engine\outputs\bigram_1830docs_20251010_165917.csv
#
#
#
# Đang xử lý 1830 documents cho 3-gram...
# Processing 3-gram: 100%|██████████| 1830/1830 [00:43<00:00, 41.73it/s]
# ================================================================================
# TOP 100 3-GRAM
# ================================================================================
#  Rank                     Phrase  Frequency  Pr(%)
#     1               kim sang sik        616   0.08
#     2           bóng_đá việt nam        614   0.08
#     3               hlv kim sang        512   0.07
#     4             asean cup 2024        472   0.06
#     5              park hang seo        356   0.05
#     6           cầu_thủ việt nam        346   0.05
#     7               sân hàng đẫy        343   0.05
#     8           league 2024 2025        294   0.04
#     9               ảnh đức đồng        294   0.04
#    10                 clb tp hcm        282   0.04
#    11             ảnh hiếu lương        276   0.04
#    12              hlv park hang        262   0.04
#    13              bùi tiến dũng        259   0.03
#    14                đội chủ nhà        249   0.03
#    15         đội_tuyển việt nam        242   0.03
#    16             tuyển việt nam        241   0.03
#    17           nguyễn quang hải        233   0.03
#    18             giải hạng nhất        224   0.03
#    19           nguyễn tiến linh        223   0.03
#    20               sân việt trì        219   0.03
#    21                đỗ duy mạnh        212   0.03
#    22               quế ngọc hải        202   0.03
#    23             asian cup 2027        192   0.03
#    24           nguyễn hoàng đức        185   0.02
#    25               thầy trò hlv        182   0.02
#    26              phạm tuấn hải        181   0.02
#    27       diễn_biến chính trận        179   0.02
#    28           league 2023 2024        178   0.02
#    29                sân mỹ đình        172   0.02
#    30               đặng văn lâm        170   0.02
#    31           sân thiên trường        158   0.02
#    32               vũ văn thanh        156   0.02
#    33            nguyễn văn toàn        156   0.02
#    34              sang hiệp hai        155   0.02
#    35          hlv park hang_seo        142   0.02
#    36       vòng_loại cuối asian        141   0.02
#    37             cuối asian cup        141   0.02
#    38          tiền_đạo sinh năm        141   0.02
#    39       afc champions league        140   0.02
#    40                phút bù thứ        140   0.02
#    41                đội bóng xứ        138   0.02
#    42              vũ tiến thành        137   0.02
#    43            nguyễn hai long        136   0.02
#    44             bùi hoàng việt        135   0.02
#    45               ảnh lâm thoả        134   0.02
#    46              việt nam thua        134   0.02
#    47               đoàn văn hậu        133   0.02
#    48               đua trụ hạng        132   0.02
#    49            chu đình nghiêm        132   0.02
#    50              trận việt nam        130   0.02
#    51              trận gần nhất        130   0.02
#    52             hoàng việt anh        127   0.02
#    53               bàn mở tỷ_số        126   0.02
#    54                 hồ tấn tài        124   0.02
#    55    vòng_loại hai world_cup        124   0.02
#    56               đội bóng phố        123   0.02
#    57      giải vô_địch quốc_gia        118   0.02
#    58               vũ hồng việt        115   0.02
#    59            đội bóng thủ_đô        115   0.02
#    60               bóng phố núi        113   0.02
#    61          nguyễn đình triệu        111   0.01
#    62            vô_địch aff cup        111   0.01
#    63         nguyễn thành chung        110   0.01
#    64         hai world_cup 2026        108   0.01
#    65          việt_nam thái lan        106   0.01
#    66           nguyễn văn quyết        106   0.01
#    67             asian cup 2023        106   0.01
#    68                hlv vũ hồng        106   0.01
#    69               đội bóng hlv        106   0.01
#    70               lê huỳnh đức        106   0.01
#    71               đầu hiệp hai        105   0.01
#    72               việt nam vff        105   0.01
#    73               hlv chu đình        104   0.01
#    74               phan văn đức        103   0.01
#    75              mang dòng máu        102   0.01
#    76            khuất văn khang        101   0.01
#    77               aff cup 2018        101   0.01
#    78             bảng asean cup        100   0.01
#    79     chuyên_nghiệp việt nam        100   0.01
#    80      hiệu_số bàn thắng_bại         99   0.01
#    81              đoàn quân hlv         99   0.01
#    82               u23 việt nam         99   0.01
#    83                 bùi vĩ hào         99   0.01
#    84                hlv vũ tiến         98   0.01
#    85                phút bù giờ         97   0.01
#    86               đội bóng đất         97   0.01
#    87              doãn ngọc tân         97   0.01
#    88               dòng máu lai         96   0.01
#    89              2024 2025 sân         96   0.01
#    90           tạo nhiều cơ_hội         95   0.01
#    91              shin tae yong         95   0.01
#    92              nguyễn văn vĩ         94   0.01
#    93               aff cup 2024         93   0.01
#    94             phạm xuân mạnh         92   0.01
#    95 bóng_đá chuyên_nghiệp việt         92   0.01
#    96                ghi hai bàn         91   0.01
#    97              mở tỷ_số phút         89   0.01
#    98               lần gần nhất         89   0.01
#    99             trước việt nam         88   0.01
#   100                lần thứ hai         85   0.01
#
# ✓ Đã lưu kết quả 3-gram vào: d:\data\Search_Engine\outputs\trigram_1830docs_20251010_170002.csv
#
#
#
# Đang xử lý 1830 documents cho 4-gram...
# Processing 4-gram: 100%|██████████| 1830/1830 [00:40<00:00, 44.70it/s]
# ================================================================================
# TOP 100 4-GRAM
# ================================================================================
#  Rank                                Phrase  Frequency  Pr(%)
#     1                      hlv kim sang sik        513   0.07
#     2                     hlv park hang seo        260   0.04
#     3              vòng_loại cuối asian cup        139   0.02
#     4                    bùi hoàng việt anh        128   0.02
#     5                   cuối asian cup 2027        120   0.02
#     6                      đội bóng phố núi        112   0.02
#     7                      hlv vũ hồng việt        105   0.01
#     8                   hlv chu đình nghiêm        103   0.01
#     9          vòng_loại hai world_cup 2026        102   0.01
#    10                     hlv vũ tiến thành         98   0.01
#    11        bóng_đá chuyên_nghiệp việt nam         92   0.01
#    12                     mang dòng máu lai         89   0.01
#    13                  league 2024 2025 sân         79   0.01
#    14            liên_đoàn bóng_đá việt nam         77   0.01
#    15                      việt trì phú thọ         75   0.01
#    16                   bảng asean cup 2024         74   0.01
#    17             bảng vòng_loại cuối asian         72   0.01
#    18 công_ty cổ_phần bóng_đá chuyên_nghiệp         72   0.01
#    19    cổ_phần bóng_đá chuyên_nghiệp việt         72   0.01
#    20                 cầu_thủ mang dòng máu         71   0.01
#    21            chuyên_nghiệp việt nam vpf         69   0.01
#    22              chung_kết asean cup 2024         68   0.01
#    23                   2024 ảnh hiếu lương         67   0.01
#    24                      sân việt trì phú         65   0.01
#    25                night wolf league 2023         65   0.01
#    26             thủ_môn nguyễn đình triệu         64   0.01
#    27                 nguyễn phong hồng duy         61   0.01
#    28                    lê phạm thành long         61   0.01
#    29                  hlv nguyễn đức thắng         59   0.01
#    30                    đội bóng thành nam         59   0.01
#    31                     hlv shin tae yong         58   0.01
#    32                     đội bóng xứ thanh         57   0.01
#    33                 nhà cầm_quân hàn quốc         55   0.01
#    34              afc champions league two         55   0.01
#    35                   hlv phan thanh hùng         54   0.01
#    36              tiền_vệ nguyễn quang hải         54   0.01
#    37                     lđbđ việt nam vff         54   0.01
#    38                     cuộc đua trụ hạng         53   0.01
#    39                    asean cup 2024 ảnh         52   0.01
#    40           world_cup 2026 khu_vực châu         51   0.01
#    41                    ghi nhiều bàn nhất         51   0.01
#    42                      hlv lê huỳnh đức         51   0.01
#    43                tiền_đạo sinh năm 1997         50   0.01
#    44                   sân hàng đẫy hà_nội         49   0.01
#    45                   vòng bảng asean cup         49   0.01
#    46                      cup clb đông nam         49   0.01
#    47    tiền_đạo nhập_tịch nguyễn xuân_son         49   0.01
#    48                      sân hàng đẫy tối         48   0.01
#    49                  thủ_môn đặng văn lâm         48   0.01
#    50                     cup nay asean cup         48   0.01
#    51                   vòng bảng asian cup         47   0.01
#    52                 thủ_môn bùi tiến dũng         46   0.01
#    53                     aff cup nay asean         46   0.01
#    54                      đội bóng xứ nghệ         46   0.01
#    55                  bóng_đá việt nam vff         45   0.01
#    56                     mừng bàn mở tỷ_số         44   0.01
#    57                 nhà cầm_quân sinh năm         44   0.01
#    58                 hlv trương việt hoàng         44   0.01
#    59                     play off trụ hạng         44   0.01
#    60                      thầy trò hlv kim         44   0.01
#    61                vô_địch asean cup 2024         43   0.01
#    62                    bàn thắng đẹp nhất         43   0.01
#    63                  league 2024 2025 ảnh         43   0.01
#    64           world_cup 2022 khu_vực châu         42   0.01
#    65                     vòng bảng aff cup         42   0.01
#    66                  vô_địch aff cup 2018         41   0.01
#    67                tiền_đạo phạm tuấn hải         41   0.01
#    68               giải hạng nhất quốc_gia         41   0.01
#    69             tiền_đạo nguyễn tiến linh         41   0.01
#    70                   bảng asian cup 2023         41   0.01
#    71                     thái lan việt nam         40   0.01
#    72                     hlv phạm minh đức         40   0.01
#    73                    thời hlv park hang         39   0.01
#    74                bán_kết asean cup 2024         39   0.01
#    75                      mùa giải năm nay         38   0.01
#    76              thủ_môn trần nguyên mạnh         38   0.01
#    77                đội_trưởng đỗ duy mạnh         38   0.01
#    78                     hc vàng sea games         37   0.01
#    79                 vòng league 2025 2026         37   0.01
#    80                       đến phút bù thứ         37   0.01
#    81                trung_vệ bùi tiến dũng         37   0.01
#    82               vòng chung_kết u23 châu         36   0.00
#    83              luật bàn thắng sân_khách         36   0.00
#    84              tiền_vệ nguyễn hoàng đức         36   0.00
#    85                    trận việt nam thua         36   0.00
#    86               lượt hai bảng vòng_loại         35   0.00
#    87               hai bảng vòng_loại cuối         35   0.00
#    88                    võ hoàng minh khoa         35   0.00
#    89                     sân hàng đẫy ngày         35   0.00
#    90                      phải đá play off         35   0.00
#    91                      trò hlv kim sang         35   0.00
#    92                   wolf league 2023 24         35   0.00
#    93                 trận_đấu sân hàng đẫy         34   0.00
#    94                     đội bóng đất cảng         34   0.00
#    95         trung_tâm đào_tạo bóng_đá trẻ         34   0.00
#    96            hai world_cup 2026 khu_vực         33   0.00
#    97                   lượt cuối vòng bảng         33   0.00
#    98           vòng_loại ba world_cup 2026         33   0.00
#    99                     cup 2024 ảnh hiếu         33   0.00
#   100                     2025 sân hàng đẫy         33   0.00
#
# ✓ Đã lưu kết quả 4-gram vào: d:\data\Search_Engine\outputs\fourgram_1830docs_20251010_170045.csv
#
#
#
# Đang xử lý 1830 documents cho 5-gram...
# Processing 5-gram: 100%|██████████| 1830/1830 [00:31<00:00, 58.57it/s]
# ================================================================================
# TOP 100 5-GRAM
# ================================================================================
#  Rank                                     Phrase  Frequency  Pr(%)
#     1              vòng_loại cuối asian cup 2027        121   0.02
#     2 công_ty cổ_phần bóng_đá chuyên_nghiệp việt         72   0.01
#     3     cổ_phần bóng_đá chuyên_nghiệp việt nam         72   0.01
#     4              bảng vòng_loại cuối asian cup         72   0.01
#     5         bóng_đá chuyên_nghiệp việt nam vpf         69   0.01
#     6                       sân việt trì phú thọ         66   0.01
#     7                  cầu_thủ mang dòng máu lai         63   0.01
#     8                      aff cup nay asean cup         47   0.01
#     9             liên_đoàn bóng_đá việt nam vff         43   0.01
#    10                     thời hlv park hang seo         38   0.01
#    11                      thầy trò hlv kim sang         35   0.00
#    12                       trò hlv kim sang sik         35   0.00
#    13               lượt hai bảng vòng_loại cuối         35   0.00
#    14              hai bảng vòng_loại cuối asian         35   0.00
#    15                  night wolf league 2023 24         35   0.00
#    16                    cup 2024 ảnh hiếu lương         33   0.00
#    17            hai world_cup 2026 khu_vực châu         33   0.00
#    18                   vòng bảng asean cup 2024         32   0.00
#    19                    asean cup 2024 ảnh hiếu         31   0.00
#    20                   vòng bảng asian cup 2023         31   0.00
#    21                     2024 2025 sân hàng đẫy         31   0.00
#    22                   sân hàng đẫy hà_nội ngày         31   0.00
#    23            hạng nhất quốc_gia cup quốc_gia         31   0.00
#    24                  fpt play https fptplay vn         31   0.00
#    25       vòng_loại hai world_cup 2026 khu_vực         30   0.00
#    26                night wolf league 2023 2024         30   0.00
#    27              league hạng nhất quốc_gia cup         30   0.00
#    28                   đỉnh nhất fpt play https         30   0.00
#    29                nhất fpt play https fptplay         30   0.00
#    30              lượt chung_kết asean cup 2024         29   0.00
#    31                  league 2024 2025 sân hàng         29   0.00
#    32                    cuối asian cup 2027 sân         29   0.00
#    33            truyền_hình fpt fpt play đơn_vị         29   0.00
#    34             nhất quốc_gia cup quốc_gia xem         29   0.00
#    35            quốc_gia cup quốc_gia xem night         29   0.00
#    36                cup quốc_gia xem night wolf         29   0.00
#    37             quốc_gia xem night wolf league         29   0.00
#    38                 xem night wolf league 2023         29   0.00
#    39                   wolf league 2023 24 đỉnh         29   0.00
#    40                   league 2023 24 đỉnh nhất         29   0.00
#    41                      2023 24 đỉnh nhất fpt         29   0.00
#    42                      24 đỉnh nhất fpt play         29   0.00
#    43                     quả bóng vàng việt nam         28   0.00
#    44                trung_vệ bùi hoàng việt anh         27   0.00
#    45      công_ty_tnhh truyền_hình fpt fpt play         27   0.00
#    46                  vòng league 2025 2026 sân         27   0.00
#    47                  hai trận sân_nhà hai trận         26   0.00
#    48            trận sân_nhà hai trận sân_khách         26   0.00
#    49                       hai đội nhất hai đội         26   0.00
#    50                       đội nhất hai đội nhì         26   0.00
#    51                      thầy trò kim sang sik         26   0.00
#    52              fpt fpt play đơn_vị phát_sóng         26   0.00
#    53        fpt play đơn_vị phát_sóng trực_tiếp         26   0.00
#    54   play đơn_vị phát_sóng trực_tiếp trọn_vẹn         26   0.00
#    55   đơn_vị phát_sóng trực_tiếp trọn_vẹn giải         26   0.00
#    56   phát_sóng trực_tiếp trọn_vẹn giải league         26   0.00
#    57        trực_tiếp trọn_vẹn giải league hạng         26   0.00
#    58             trọn_vẹn giải league hạng nhất         26   0.00
#    59             giải league hạng nhất quốc_gia         26   0.00
#    60                       đá play off trụ hạng         25   0.00
#    61                điểm thi_đấu nhiều hơn trận         25   0.00
#    62                      ngày 12 2024 đến 2025         25   0.00
#    63                        10 đội chia làm hai         25   0.00
#    64                      đội chia làm hai bảng         25   0.00
#    65          ra_quân bảng vòng_loại cuối asian         25   0.00
#    66                 chia_sẻ bài viết bạn trang         24   0.00
#    67                  bài viết bạn trang ý_kiến         24   0.00
#    68                        12 2024 đến 2025 10         24   0.00
#    69                       2024 đến 2025 10 đội         24   0.00
#    70                       đến 2025 10 đội chia         24   0.00
#    71                       2025 10 đội chia làm         24   0.00
#    72                      chọn hai đội nhất hai         24   0.00
#    73                   nhất hai đội nhì bán_kết         24   0.00
#    74                    bảng asean cup 2024 ảnh         24   0.00
#    75                      cup clb đông nam 2024         24   0.00
#    76                     clb đông nam 2024 2025         24   0.00
#    77             cup quốc_gia siêu cup quốc_gia         24   0.00
#    78           lượt ra_quân bảng vòng_loại cuối         24   0.00
#    79                   tổ_chức ngày 12 2024 đến         23   0.00
#    80                  chia làm hai bảng thi_đấu         23   0.00
#    81            sân_nhà hai trận sân_khách chọn         23   0.00
#    82                hai trận sân_khách chọn hai         23   0.00
#    83                trận sân_khách chọn hai đội         23   0.00
#    84                sân_khách chọn hai đội nhất         23   0.00
#    85                    đổi tên thành asean cup         22   0.00
#    86                   làm hai bảng thi_đấu hai         22   0.00
#    87                  hai bảng thi_đấu hai trận         22   0.00
#    88              bảng thi_đấu hai trận sân_nhà         22   0.00
#    89               thi_đấu hai trận sân_nhà hai         22   0.00
#    90                   hai đội nhì bán_kết vòng         22   0.00
#    91               đội nhì bán_kết vòng cặp_đấu         22   0.00
#    92              nhì bán_kết vòng cặp_đấu diễn         22   0.00
#    93              bán_kết vòng cặp_đấu diễn hai         22   0.00
#    94                 vòng cặp_đấu diễn hai lượt         22   0.00
#    95             cặp_đấu diễn hai lượt thể_thức         22   0.00
#    96             diễn hai lượt thể_thức lượt_đi         22   0.00
#    97             hai lượt thể_thức lượt_đi tính         22   0.00
#    98            lượt thể_thức lượt_đi tính luật         22   0.00
#    99             thể_thức lượt_đi tính luật bàn         22   0.00
#   100                lượt_đi tính luật bàn thắng         22   0.00
#
# ✓ Đã lưu kết quả 5-gram vào: d:\data\Search_Engine\outputs\fivegram_1830docs_20251010_170118.csv
#
#
#
# ✓ Đã đóng kết nối database
# ✓ HOÀN THÀNH!
#
# 📁 Tất cả kết quả đã được lưu vào folder: d:\data\Search_Engine\outputs

# %%
# ============================================
# Build Inverted Index from JSON Articles and Store to MongoDB
# ============================================

import os
import json
import re
from pymongo import MongoClient
from tqdm import tqdm

# ==============================
# 1. MongoDB Connection
# ==============================
mongo_url = "mongodb+srv://group2user1:eRqZZqR3VQA4NPLd@cluster0.orljj0v.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"  # e.g. "mongodb+srv://user:pass@cluster.mongodb.net"
client = MongoClient(mongo_url)
db = client["vnexpress_bongda"]
collection = db["inverted_index"]

# ==============================
# 2. Load All JSON Files
# ==============================
data_files = [
    "vnexpressT_bongda_part1.json",
    "vnexpressT_bongda_part2.json",
    "vnexpressT_bongda_part3.json",
    "vnexpressT_bongda_part4.json"
]

articles = []
for file_path in data_files:
    if os.path.exists(file_path):
        with open(file_path, "r", encoding="utf-8") as f:
            try:
                articles.extend(json.load(f))
            except json.JSONDecodeError as e:
                print(f"⚠️ Error reading {file_path}: {e}")
    else:
        print(f"⚠️ File not found: {file_path}")

print(f"✅ Loaded {len(articles)} articles from {len(data_files)} files")

# ==============================
# 3. Preprocess and Tokenize
# ==============================
def preprocess_text(text):
    """Lowercase + remove special characters + tokenize words."""
    text = text.lower()
    text = re.sub(r"http\S+", "", text)           # remove URLs
    text = re.sub(r"[^a-zA-Z0-9àáảãạăắằẳẵặâấầẩẫậèéẻẽẹêếềểễệìíỉĩịòóỏõọ"
                  r"ôốồổỗộơớờởỡợùúủũụưứừửữựỳýỷỹỵđ\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    tokens = text.split(" ")
    return [t for t in tokens if t]

# ==============================
# 4. Build Inverted Index
# ==============================
inverted_index = {}

print("🔍 Building inverted index...")
for idx, article in enumerate(tqdm(articles, total=len(articles))):
    doc_id = article.get("url") or f"doc_{idx}"
    content = (article.get("title", "") + " " + article.get("content", "")).strip()
    tokens = preprocess_text(content)
    unique_tokens = set(tokens)
    
    for token in unique_tokens:
        if token not in inverted_index:
            inverted_index[token] = [doc_id]
        else:
            inverted_index[token].append(doc_id)

print(f"✅ Inverted index built with {len(inverted_index)} unique terms")

# ==============================
# 5. Store Inverted Index to MongoDB
# ==============================
print("💾 Storing inverted index to MongoDB...")
collection.delete_many({})  # clear existing
records = [{"term": term, "documents": docs} for term, docs in inverted_index.items()]
if records:
    collection.insert_many(records)
    print(f"✅ Stored {len(records)} terms into MongoDB collection '{collection.name}'")
else:
    print("⚠️ No records to store")

# ==============================
# 6. Save Locally
# ==============================
output_path = "inverted_index.json"
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(inverted_index, f, ensure_ascii=False, indent=2)
print(f"✅ Inverted index saved locally to '{output_path}'")

# ==============================
# 7. Example Query
# ==============================
def search():
    query = input("Enter search term: ").strip().lower()
    return query
    
query = search()
query_tokens = preprocess_text(query)
for q in query_tokens:
    res = collection.find_one({"term": q})
    if res:
        print(f"\n🔎 Term '{q}' found in {len(res['documents'])} articles:")
        print(res["documents"][:5])  # show first 5 docs
    else:
        print(f"\n⚠️ Term '{q}' not found in database.")
# Out:
# ✅ Loaded 1831 articles from 4 files
# 🔍 Building inverted index...
# 100%|██████████| 1831/1831 [00:01<00:00, 1202.41it/s]
# ✅ Inverted index built with 8893 unique terms
# 💾 Storing inverted index to MongoDB...
# ✅ Stored 8893 terms into MongoDB collection 'inverted_index'
# ✅ Inverted index saved locally to 'inverted_index.json'
#
# 🔎 Term 'công' found in 1372 articles:
# ['https://vnexpress.net/u23-viet-nam-u23-yemen-u23-viet-nam-thuong-chau-ao-tuong-bong-da-viet-nam-vuon-tam-khi-gianh-ve-du-vck-u23-chau-a-4937349.html', 'https://vnexpress.net/lieu-malaysia-co-bi-xu-thua-tran-viet-nam-4944224.html', 'https://vnexpress.net/bao-nhat-ban-them-mot-lan-muoi-mat-truoc-bong-da-viet-nam-4871369.html', 'https://vnexpress.net/doi-tuyen-viet-nam-thua-dam-nam-dinh-4935227.html', 'https://vnexpress.net/tuyen-viet-nam-tim-lai-niem-vui-chien-thang-4936221.html']
#
# 🔎 Term 'an' found in 574 articles:
# ['https://vnexpress.net/doi-tuyen-viet-nam-thua-dam-nam-dinh-4935227.html', 'https://vnexpress.net/hlv-quang-nam-van-nan-trong-tai-keo-bong-da-viet-nam-di-xuong-4850021.html', 'https://vnexpress.net/agribank-thuong-doi-tuyen-bong-da-viet-nam-1-ty-dong-4834668.html', 'https://vnexpress.net/cau-thu-tre-tp-hcm-xin-loi-vi-lam-xau-hinh-anh-bong-da-viet-nam-4816302.html', 'https://vnexpress.net/so-phan-cua-10-ngoi-sao-bong-da-viet-nam-tung-xuat-ngoai-4796211.html']
